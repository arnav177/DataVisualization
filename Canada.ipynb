# %%
import pandas as pd

# %%
df_can=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.csv')

# %%
years=list(map(str, range(1980,2014)))
years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
df_can.sort_values(['Total'], ascending=False, axis=0,     inplace=True)

df_top5=df_can.head()

df_top5=df_top5[years].transpose()

df_top5.head()
# Out:
#        79    36     183   136   130
# 1980  8880  5123  22045  6051   978
# 1981  8670  6682  24796  5921   972
# 1982  8147  3308  20620  5249  1201
# 1983  7338  1863  10015  4562   900
# 1984  5704  1527  10170  3801   668

# %%
df_top5 = df_can.loc[['India','China'] , years].transpose()
df_top5
# Out:
# Country  India  China
# 1980      8880   5123
# 1981      8670   6682
# 1982      8147   3308
# 1983      7338   1863
# 1984      5704   1527
# 1985      4211   1816
# 1986      7150   1960
# 1987     10189   2643
# 1988     11522   2758
# 1989     10343   4323
# 1990     12041   8076
# 1991     13734  14255
# 1992     13673  10846
# 1993     21496   9817
# 1994     18620  13128
# 1995     18489  14398
# 1996     23859  19415
# 1997     22268  20475
# 1998     17241  21049
# 1999     18974  30069
# 2000     28572  35529
# 2001     31223  36434
# 2002     31889  31961
# 2003     27155  36439
# 2004     28235  36619
# 2005     36210  42584
# 2006     33848  33518
# 2007     28742  27642
# 2008     28261  30037
# 2009     29456  29622
# 2010     34235  30391
# 2011     27509  28502
# 2012     30933  33024
# 2013     33087  34129

# %%
df_can.sort_values(['Total'], ascending=False, axis=0,     inplace=True)

df_top15=df_can.head(15)

df_top15=df_top15[years].transpose()

df_top15.head(15)
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
# 1985      4211   1816                                               9564
# 1986      7150   1960                                               9470
# 1987     10189   2643                                              21337
# 1988     11522   2758                                              27359
# 1989     10343   4323                                              23795
# 1990     12041   8076                                              31668
# 1991     13734  14255                                              23380
# ...

# %%
df_can = pd.read_csv('Canada.csv')
skiprows=range(20)
df_can
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
df_can.set_index('Country' , inplace= True)

# %%
years=list(map(str  ,range(1980,2014)))
india =df_can.loc['India',years]
india.head()
# Out:
# 1980    8880
# 1981    8670
# 1982    8147
# 1983    7338
# 1984    5704
# Name: India, dtype: object

# %%
df_top5.index=df_top5.index.map(int)
df_top5.head()
# Out:
#        79    36     183   136   130
# 1980  8880  5123  22045  6051   978
# 1981  8670  6682  24796  5921   972
# 1982  8147  3308  20620  5249  1201
# 1983  7338  1863  10015  4562   900
# 1984  5704  1527  10170  3801   668

# %%
df_can.sort_values(['Total'],ascending=False,axis=0,inplace=True)
df_top5= df_can.head()


df_top5 = df_top5[years].transpose()
df_top5.head()
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
#
# Country  Philippines  Pakistan
# 1980            6051       978
# 1981            5921       972
# 1982            5249      1201
# 1983            4562       900
# 1984            3801       668

# %%
df_top5.plot(kind='line')
# Out:
# <Axes: >

# %%
df_top15.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_can.head()
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
import matplotlib.pyplot as plt
df_top5.plot(kind='area',  stacked='False', figsize = (20,10))

plt.title('Immigration trend of top5 countries')
plt.ylabel('Number of immigrants')
plt.xlabel('years')
plt.show()

# %%
df_top5.plot(kind='area',
             alpha=0.51,
             stacked=False,
             figsize=(20,10))

plt.title('Immigrants Trend of top5 countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('years')
plt.show()

# %%
ax = df_top5.plot(kind='area',
                  alpha=0.51,
                  stacked=False,
                  figsize=(20,10))

ax.set_title('Immigrants Trend of top5 countries')
ax.set_ylabel('Number of Immigrants')
ax.set_xlabel('years')
plt.show()

# %%
df_can['2013'].head()
# Out:
# Country
# India                                                   33087
# China                                                   34129
# United Kingdom of Great Britain and Northern Ireland     5827
# Philippines                                             29544
# Pakistan                                                12603
# Name: 2013, dtype: int64

# %%
import numpy as np

# %%
count, bin_edges=np.histogram(df_can['2013'])

print(count)
print(bin_edges)
# Out:
# [178  11   1   2   0   0   0   0   1   2]
# [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %%
df_can['2013'].plot(kind='hist', figsize = (8,5))

plt.title('Histogram of immigration from 195 countries to 2013')
plt.ylabel('Number of countries')
plt.xlabel('years')

plt.show()

# %%
df_can.loc[['Denmark','Sweden','Norway'], years]

# %%
df_can.loc[['Denmark','Sweden','Norway'], years].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_s = df_can.loc[['Denmark','Sweden','Norway'], years].transpose()
df_s.head()
# Out:
#       Denmark  Sweden  Norway
# 1980      272     281     116
# 1981      293     308      77
# 1982      299     222     106
# 1983      106     176      51
# 1984       93     128      31

# %%
df_k = df_can.loc[['France','Indonesia'],years].transpose()
df_k.head()
# Out:
# Country  France  Indonesia
# 1980       1729        186
# 1981       2027        178
# 1982       2219        252
# 1983       1490        115
# 1984       1169        123

# %%
count, bin_edges=np.histogram(df_s,15)

df_s.plot(kind='hist',
          figsize= (10,6),
          bins = 15,
          alpha = 0.6,
          
          color=['coral', 'darkslateblue','mediumseagreen']
          )

plt.title('Immigration from Norway and Sweden to Canada from 1980 - 2013')
plt.xlabel('Number of immigrants')
plt.ylabel('years')
plt.show()

# %%
count, bin_edges=np.histogram(df_s,15)
xmin = bin_edges[0]-10
xmax = bin_edges[-1]+10

df_s.plot(kind='hist',
          figsize= (10,6),
          bins=15,
          xticks=bin_edges,
          color= ['coral', 'darkslateblue','mediumseagreen'],
          stacked=True,
          xlim=(xmin,xmax)
          )

plt.title('Immigration from Norway and Sweden to Canada from 1980 - 2013')
plt.xlabel('Number of immigrants')
plt.ylabel('years')
plt.show()

# %%
df_can.loc[['Greece','Albania','Bulgaria'],years]
# Out:
#           1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  \
# Country                                                               ...
# Greece    1065   953   897   633   580   584   547   765   564   773  ...
# Albania      1     0     0     0     0     0     1     2     2     3  ...
# Bulgaria    24    20    12    33    11    24    33    52    43    85  ...
#
#           2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# Country
# Greece     120   100    74   110   107   119   101   102   146   298
# Albania   1450  1223   856   702   560   716   561   539   620   603
# Bulgaria  2022  1738  1419  1172   994   784   556   365   451   512
#
# [3 rows x 34 columns]

# %%
s = df_can.loc[['Greece','Albania','Bulgaria'],years].transpose()
s
s.head()
# Out:
# Country  Greece  Albania  Bulgaria
# 1980       1065        1        24
# 1981        953        0        20
# 1982        897        0        12
# 1983        633        0        33
# 1984        580        0        11

# %%
s.plot(kind='box')
# Out:
# <Axes: >

# %%
s.plot(kind='barh')
# Out:
# <Axes: >

# %%
import numpy as np

# %%
count, bin_edges=np.histogram(s,15)
xmin = bin_edges[0]-10
xmax = bin_edges[-1]+10

s.plot(kind='hist',
       
       figsize= (10,6),
       bins=15,
       xticks=bin_edges,
       color= ['pink', 'red','darkblue'],
       stacked=True,
       xlim=(xmin,xmax)
       )

plt.title('Immigration from Greece ,Albania, and Sweden to Canada from 1980 - 2013')
plt.xlabel('Number of immigrants')
plt.ylabel('years')
plt.show()

# %%
df_iceland = df_can.loc['Iceland',years]
df_iceland.head()
# Out:
# 1980    17
# 1981    33
# 1982    10
# 1983     9
# 1984    13
# Name: Iceland, dtype: object

# %%
df_iceland.plot(kind='bar',figsize=(10,6))
plt.xlabel('year')
plt.ylabel('Number of immigrants from iceland to canada from 1980 - 2013')

plt.show()

# %%
df_can.head()
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
print(df_can.shape)
# Out:
# (195, 38)

# %%
print(df_can.columns.tolist())
# Out:
# ['Continent', 'Region', 'DevName', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', 'Total']

# %%
years = list(map(str,  range(1980,2014)))

# %%
df_continents = df_can.groupby('Continent', axis=0).sum()
df_continents.head()
# Out:
# C:\Users\Arnav\AppData\Local\Temp\ipykernel_12944\3645796068.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_continents = df_can.groupby('Continent', axis=0).sum()
#                                   1980   1981   1982   1983   1984   1985  \
# Continent
# Africa                            3951   4363   3819   2671   2639   2650
# Asia                             31025  34314  30214  24696  27274  23850
# Europe                           39760  44802  42720  24638  22287  20844
# Latin America and the Caribbean  13081  15215  16769  15427  13678  15171
# Northern America                  9378  10030   9074   7100   6661   6543
#
#                                   1986   1987   1988   1989  ...    2005  \
# Continent                                                    ...
# ...

# %%
df_continents['Total'].plot(kind='pie',
                            figsize=(5,6),
                            autopct='%1.1f%%',
                            startangle=90,
                            shadow=True,
                           )

plt.title('Immigration to Canada by Continent [1980-2013]')
plt.axis('equal')
plt.legend(labels=df_continents.index, loc='upper left')

plt.show()

# %%
colors_list = ['gold','yellowgreen','lightcoral','lightskyblue','lightgreen','pink']

df_continents['Total'].plot(kind='pie',
                            figsize=(5,6),
                            autopct='%1.0f%%',
                            startangle=90,
                            shadow=True,
                            labels=None,
                            pctdistance=1.12,
                           )

plt.title('Immigration to Canada by Continent [1980-2013]', y=1.12,fontsize=15)

plt.axis('equal')
plt.legend(labels=df_continents.index,loc='upper left',fontsize = 7)
plt.show()

# %%
colors_list = ['gold','yellowgreen','lightcoral','lightskyblue','lightgreen','pink']

df_continents['Total'].plot(kind='pie',
                            figsize=(5,6),
                            autopct='%1.0f%%',
                            startangle=90,
                            shadow=True,
                            labels=None,
                            pctdistance=1.12,
                           )

plt.title('Immigration to Canada by Continent [2013]', y=1.12,fontsize=15)

plt.axis('equal')
plt.legend(labels=df_continents.index,loc='upper left',fontsize = 7)
plt.show()

# %%
print(df_can.shape)
# Out:
# (195, 38)

# %%
df_top5.index=df_top5.index.map(int)
df_top5.plot(kind='area',stacked=False,figsize=(20,10))

plt.title('Number of immigrants from top5 contries')
plt.ylabel('Number of Immigrants')
plt.xlabel('years')

plt.show()

# %%
df_top5.index=df_top5.index.map(int)
df_top5.plot(kind='hist',stacked=False,figsize=(20,10))

plt.title('Number of immigrants from top5 contries')
plt.ylabel('Number of Immigrants')
plt.xlabel('years')

plt.show()

# %%
df_can.sort_values(['Total'],ascending=False,axis=0,inplace=True)

df_least5=df_can.tail()
df_least5=df_least5[years].transpose()
df_least5.tail()
# Out:
# Country  San Marino  New Caledonia  Marshall Islands  Western Sahara  Palau
# 2009              0              0                 0               0      0
# 2010              1              0                 0               0      0
# 2011              0              0                 0               0      0
# 2012              0              0                 0               0      0
# 2013              0              2                 0               0      0

# %%
import matplotlib.pyplot as plt
df_least5.plot(kind='area',figsize=(23,12),stacked=False)

plt.title('Immigration from least5 countries to canada from 1980 to 2014')
plt.ylabel('Number of immigrants')
plt.xlabel('years')

plt.show()
